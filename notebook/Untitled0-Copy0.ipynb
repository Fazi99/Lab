# %%
import pandas as pd
import datetime
# %matplotlib inline

# %%
data = pd.read_csv("/home/faizan/Desktop/output_indices.csv")

# %%
dates = [datetime.datetime.strptime(str(i[]), "%Y%j") for i in data["DATE"]]
data.index = dates

# %%
ndvi = data.NDVI
evi = data.EVI
lswi = data.LSWI
lswi.plot()
evi.plot()
ndvi.plot(figsize=(18,5))

# %%
date = "A2000097"
date[1:]
# Out:
# '2000097'

# %%
dummy = data[data.index.year > 2009]
evi = dummy.EVI[dummy.index.year < 2011]
evi.plot()

# %%
dummy
# Out:
# Empty DataFrame
# Columns: [sr.no, DATE, NDVI, EVI, LSWI, DVEL, Flood]
# Index: []
